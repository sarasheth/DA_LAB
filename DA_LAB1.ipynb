# %% [markdown]
# <a href="https://colab.research.google.com/github/sarasheth/DA_LAB/blob/main/DA_LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload();
data = pd.read_csv("HT_2013-2020.csv");
data
# Out:
#      <input type="file" id="files-24ce6363-8aa0-4763-ad6a-736db1c210c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24ce6363-8aa0-4763-ad6a-736db1c210c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HT_2013-2020.csv to HT_2013-2020.csv
#       DATA_YEAR        ORI                           PUB_AGENCY_NAME  \
# 0          2016  MO0480600                              Independence
# 1          2016  TX2201200                                Fort Worth
# 2          2016  TX2270100                                    Austin
# 3          2019  NV0020100  Las Vegas Metropolitan Police Department
# 4          2017  AZ0070500                                  Chandler
# ...         ...        ...                                       ...
# 4412       2019  KY0370000                                  Franklin
# 4413       2019  KY0370000                                  Franklin
# 4414       2020  KY0370000                                  Franklin
# 4415       2020  KY0370000                                  Franklin
# 4416       2020  KY0370000                                  Franklin
#
#      PUB_AGENCY_UNIT AGENCY_TYPE_NAME STATE_ABBR STATE_NAME  \
# 0                NaN             City         MO   Missouri
# 1                NaN             City         TX      Texas
# 2                NaN             City         TX      Texas
# 3                NaN             City         NV     Nevada
# 4                NaN             City         AZ    Arizona
# ...              ...              ...        ...        ...
# 4412             NaN           County         KY   Kentucky
# 4413             NaN           County         KY   Kentucky
# 4414             NaN           County         KY   Kentucky
# 4415             NaN           County         KY   Kentucky
# 4416             NaN           County         KY   Kentucky
#
#            DIVISION_NAME              COUNTY_NAME REGION_NAME  \
# 0     West North Central                  JACKSON     Midwest
# 1     West South Central  PARKER; DENTON; TARRANT       South
# 2     West South Central       WILLIAMSON; TRAVIS       South
# 3               Mountain                    CLARK        West
# 4               Mountain                 MARICOPA        West
# ...                  ...                      ...         ...
# 4412  East South Central                 FRANKLIN       South
# 4413  East South Central                 FRANKLIN       South
# 4414  East South Central                 FRANKLIN       South
# 4415  East South Central                 FRANKLIN       South
# 4416  East South Central                 FRANKLIN       South
#
#      POPULATION_GROUP_CODE                     POPULATION_GROUP_DESC  \
# 0                        2          Cities from 100,000 thru 249,999
# 1                       1B          Cities from 500,000 thru 999,999
# 2                       1B          Cities from 500,000 thru 999,999
# 3                       1A                  Cities 1,000,000 or over
# 4                        2          Cities from 100,000 thru 249,999
# ...                    ...                                       ...
# 4412                    8C  Non-MSA counties from 10,000 thru 24,999
# 4413                    8C  Non-MSA counties from 10,000 thru 24,999
# 4414                    8C  Non-MSA counties from 10,000 thru 24,999
# 4415                    8C  Non-MSA counties from 10,000 thru 24,999
# 4416                    8C  Non-MSA counties from 10,000 thru 24,999
#
#       OFFENSE_SUBCAT_ID       OFFENSE_NAME    OFFENSE_SUBCAT_NAME  \
# 0                    81  Human Trafficking    Commercial Sex Acts
# 1                    82  Human Trafficking  Involuntary Servitude
# 2                    82  Human Trafficking  Involuntary Servitude
# 3                    81  Human Trafficking    Commercial Sex Acts
# 4                    81  Human Trafficking    Commercial Sex Acts
# ...                 ...                ...                    ...
# 4412                 82  Human Trafficking  Involuntary Servitude
# 4413                 82  Human Trafficking  Involuntary Servitude
# 4414                 81  Human Trafficking    Commercial Sex Acts
# 4415                 81  Human Trafficking    Commercial Sex Acts
# 4416                 81  Human Trafficking    Commercial Sex Acts
#
#       ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 0                2                0              2                       0
# 1                1                0              0                       0
# 2                2                0              0                       0
# 3               15                0              4                       0
# 4                1                0              0                       0
# ...            ...              ...            ...                     ...
# 4412             2                0              0                       0
# 4413             1                0              0                       0
# 4414             1                0              0                       0
# 4415             1                0              0                       0
# 4416             1                0              0                       0
#
# [4417 rows x 19 columns]

# %%
data.head()
# Out:
#    DATA_YEAR        ORI                           PUB_AGENCY_NAME  \
# 0       2016  MO0480600                              Independence
# 1       2016  TX2201200                                Fort Worth
# 2       2016  TX2270100                                    Austin
# 3       2019  NV0020100  Las Vegas Metropolitan Police Department
# 4       2017  AZ0070500                                  Chandler
#
#   PUB_AGENCY_UNIT AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME  \
# 0             NaN             City         MO   Missouri  West North Central
# 1             NaN             City         TX      Texas  West South Central
# 2             NaN             City         TX      Texas  West South Central
# 3             NaN             City         NV     Nevada            Mountain
# 4             NaN             City         AZ    Arizona            Mountain
#
#                COUNTY_NAME REGION_NAME POPULATION_GROUP_CODE  \
# 0                  JACKSON     Midwest                     2
# 1  PARKER; DENTON; TARRANT       South                    1B
# 2       WILLIAMSON; TRAVIS       South                    1B
# 3                    CLARK        West                    1A
# 4                 MARICOPA        West                     2
#
#               POPULATION_GROUP_DESC  OFFENSE_SUBCAT_ID       OFFENSE_NAME  \
# 0  Cities from 100,000 thru 249,999                 81  Human Trafficking
# 1  Cities from 500,000 thru 999,999                 82  Human Trafficking
# 2  Cities from 500,000 thru 999,999                 82  Human Trafficking
# 3          Cities 1,000,000 or over                 81  Human Trafficking
# 4  Cities from 100,000 thru 249,999                 81  Human Trafficking
#
#      OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  \
# 0    Commercial Sex Acts             2                0              2
# 1  Involuntary Servitude             1                0              0
# 2  Involuntary Servitude             2                0              0
# 3    Commercial Sex Acts            15                0              4
# 4    Commercial Sex Acts             1                0              0
#
#    JUVENILE_CLEARED_COUNT
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
data.tail()
# Out:
#       DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT AGENCY_TYPE_NAME  \
# 4412       2019  KY0370000        Franklin             NaN           County
# 4413       2019  KY0370000        Franklin             NaN           County
# 4414       2020  KY0370000        Franklin             NaN           County
# 4415       2020  KY0370000        Franklin             NaN           County
# 4416       2020  KY0370000        Franklin             NaN           County
#
#      STATE_ABBR STATE_NAME       DIVISION_NAME COUNTY_NAME REGION_NAME  \
# 4412         KY   Kentucky  East South Central    FRANKLIN       South
# 4413         KY   Kentucky  East South Central    FRANKLIN       South
# 4414         KY   Kentucky  East South Central    FRANKLIN       South
# 4415         KY   Kentucky  East South Central    FRANKLIN       South
# 4416         KY   Kentucky  East South Central    FRANKLIN       South
#
#      POPULATION_GROUP_CODE                     POPULATION_GROUP_DESC  \
# 4412                    8C  Non-MSA counties from 10,000 thru 24,999
# 4413                    8C  Non-MSA counties from 10,000 thru 24,999
# 4414                    8C  Non-MSA counties from 10,000 thru 24,999
# 4415                    8C  Non-MSA counties from 10,000 thru 24,999
# 4416                    8C  Non-MSA counties from 10,000 thru 24,999
#
#       OFFENSE_SUBCAT_ID       OFFENSE_NAME    OFFENSE_SUBCAT_NAME  \
# 4412                 82  Human Trafficking  Involuntary Servitude
# 4413                 82  Human Trafficking  Involuntary Servitude
# 4414                 81  Human Trafficking    Commercial Sex Acts
# 4415                 81  Human Trafficking    Commercial Sex Acts
# 4416                 81  Human Trafficking    Commercial Sex Acts
#
#       ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 4412             2                0              0                       0
# 4413             1                0              0                       0
# 4414             1                0              0                       0
# 4415             1                0              0                       0
# 4416             1                0              0                       0

# %%
data.sample(10)
# Out:
#       DATA_YEAR        ORI                   PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# 2198       2020  GA0330300                          Marietta             NaN
# 2407       2019  WVWSP1700                     State Police:     Harrisville
# 731        2019  MN0620900                          St. Paul             NaN
# 832        2018  TXDPD0000                            Dallas             NaN
# 2797       2018  NV0160100                              Reno             NaN
# 1800       2020  FL0360000                               Lee             NaN
# 1601       2015  WI0450100                          Appleton             NaN
# 1387       2018  TX2270100                            Austin             NaN
# 3377       2016  WA0170700                              Kent             NaN
# 1909       2018  VA0430100  Henrico County Police Department             NaN
#
#      AGENCY_TYPE_NAME STATE_ABBR     STATE_NAME       DIVISION_NAME  \
# 2198             City         GA        Georgia      South Atlantic
# 2407     State Police         WV  West Virginia      South Atlantic
# 731              City         MN      Minnesota  West North Central
# 832              City         TX          Texas  West South Central
# 2797             City         NV         Nevada            Mountain
# 1800           County         FL        Florida      South Atlantic
# 1601             City         WI      Wisconsin  East North Central
# 1387             City         TX          Texas  West South Central
# 3377             City         WA     Washington             Pacific
# 1909           County         VA       Virginia      South Atlantic
#
#                            COUNTY_NAME REGION_NAME POPULATION_GROUP_CODE  \
# 2198                              COBB       South                     3
# 2407                           RITCHIE       South                    8D
# 731                             RAMSEY     Midwest                    1C
# 832   ROCKWALL; DENTON; COLLIN; DALLAS       South                    1A
# 2797                            WASHOE        West                    1C
# 1800                               LEE       South                    9A
# 1601     WINNEBAGO; CALUMET; OUTAGAMIE     Midwest                     3
# 1387                WILLIAMSON; TRAVIS       South                    1B
# 3377                              KING        West                     2
# 1909                           HENRICO       South                    9A
#
#                  POPULATION_GROUP_DESC  OFFENSE_SUBCAT_ID       OFFENSE_NAME  \
# 2198    Cities from 50,000 thru 99,999                 81  Human Trafficking
# 2407     Non-MSA counties under 10,000                 81  Human Trafficking
# 731   Cities from 250,000 thru 499,999                 81  Human Trafficking
# 832           Cities 1,000,000 or over                 81  Human Trafficking
# 2797  Cities from 250,000 thru 499,999                 81  Human Trafficking
# 1800      MSA counties 100,000 or over                 82  Human Trafficking
# 1601    Cities from 50,000 thru 99,999                 81  Human Trafficking
# 1387  Cities from 500,000 thru 999,999                 81  Human Trafficking
# 3377  Cities from 100,000 thru 249,999                 81  Human Trafficking
# 1909      MSA counties 100,000 or over                 81  Human Trafficking
#
#         OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  \
# 2198    Commercial Sex Acts             4                0              3
# 2407    Commercial Sex Acts             1                0              1
# 731     Commercial Sex Acts             1                0              1
# 832     Commercial Sex Acts             3                0              1
# 2797    Commercial Sex Acts             2                0              1
# 1800  Involuntary Servitude             2                0              2
# 1601    Commercial Sex Acts             1                0              0
# 1387    Commercial Sex Acts             2                0              0
# 3377    Commercial Sex Acts             6                0              3
# 1909    Commercial Sex Acts             1                0              1
#
#       JUVENILE_CLEARED_COUNT
# 2198                       0
# 2407                       0
# 731                        0
# 832                        0
# 2797                       1
# 1800                       0
# 1601                       0
# 1387                       0
# 3377                       0
# 1909                       0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4417 entries, 0 to 4416
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATA_YEAR               4417 non-null   int64
#  1   ORI                     4417 non-null   object
#  2   PUB_AGENCY_NAME         4417 non-null   object
#  3   PUB_AGENCY_UNIT         214 non-null    object
#  4   AGENCY_TYPE_NAME        4417 non-null   object
#  5   STATE_ABBR              4417 non-null   object
#  6   STATE_NAME              4417 non-null   object
#  7   DIVISION_NAME           4417 non-null   object
#  8   COUNTY_NAME             4306 non-null   object
#  9   REGION_NAME             4417 non-null   object
#  10  POPULATION_GROUP_CODE   4417 non-null   object
#  11  POPULATION_GROUP_DESC   4417 non-null   object
#  12  OFFENSE_SUBCAT_ID       4417 non-null   int64
#  13  OFFENSE_NAME            4417 non-null   object
#  14  OFFENSE_SUBCAT_NAME     4417 non-null   object
#  15  ACTUAL_COUNT            4417 non-null   int64
#  16  UNFOUNDED_COUNT         4417 non-null   int64
#  17  CLEARED_COUNT           4417 non-null   int64
#  18  JUVENILE_CLEARED_COUNT  4417 non-null   int64
# dtypes: int64(6), object(13)
# memory usage: 655.8+ KB

# %%
data.dtypes
# Out:
# DATA_YEAR                  int64
# ORI                       object
# PUB_AGENCY_NAME           object
# PUB_AGENCY_UNIT           object
# AGENCY_TYPE_NAME          object
# STATE_ABBR                object
# STATE_NAME                object
# DIVISION_NAME             object
# COUNTY_NAME               object
# REGION_NAME               object
# POPULATION_GROUP_CODE     object
# POPULATION_GROUP_DESC     object
# OFFENSE_SUBCAT_ID          int64
# OFFENSE_NAME              object
# OFFENSE_SUBCAT_NAME       object
# ACTUAL_COUNT               int64
# UNFOUNDED_COUNT            int64
# CLEARED_COUNT              int64
# JUVENILE_CLEARED_COUNT     int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# DATA_YEAR                    0
# ORI                          0
# PUB_AGENCY_NAME              0
# PUB_AGENCY_UNIT           4203
# AGENCY_TYPE_NAME             0
# STATE_ABBR                   0
# STATE_NAME                   0
# DIVISION_NAME                0
# COUNTY_NAME                111
# REGION_NAME                  0
# POPULATION_GROUP_CODE        0
# POPULATION_GROUP_DESC        0
# OFFENSE_SUBCAT_ID            0
# OFFENSE_NAME                 0
# OFFENSE_SUBCAT_NAME          0
# ACTUAL_COUNT                 0
# UNFOUNDED_COUNT              0
# CLEARED_COUNT                0
# JUVENILE_CLEARED_COUNT       0
# dtype: int64

# %%
data.isna().sum()
# Out:
# DATA_YEAR                    0
# ORI                          0
# PUB_AGENCY_NAME              0
# PUB_AGENCY_UNIT           4203
# AGENCY_TYPE_NAME             0
# STATE_ABBR                   0
# STATE_NAME                   0
# DIVISION_NAME                0
# COUNTY_NAME                111
# REGION_NAME                  0
# POPULATION_GROUP_CODE        0
# POPULATION_GROUP_DESC        0
# OFFENSE_SUBCAT_ID            0
# OFFENSE_NAME                 0
# OFFENSE_SUBCAT_NAME          0
# ACTUAL_COUNT                 0
# UNFOUNDED_COUNT              0
# CLEARED_COUNT                0
# JUVENILE_CLEARED_COUNT       0
# dtype: int64

# %%
data.shape
# Out:
# (4417, 19)

# %%
'Number of duplicates:', len(data[data.duplicated()])
# Out:
# ('Number of duplicates:', 927)

# %%
# Function to calculate missing values by column# Funct 
def missing_values_table(df):
        # Total missing values
        mis_val = df.isnull().sum()
        
        # Percentage of missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        
        # Make a table with the results
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        
        # Rename the columns
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values('% of Total Values', ascending=False).round(1)
        
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) + " columns that have missing values.")
        
        # Return the dataframe with missing information
        return mis_val_table_ren_columns

missing_values_data = missing_values_table(data)

missing_values_data.head(30)
# Out:
# Your selected dataframe has 19 columns.
# There are 2 columns that have missing values.
#                  Missing Values  % of Total Values
# PUB_AGENCY_UNIT            4203               95.2
# COUNTY_NAME                 111                2.5

# %%
data.dtypes.value_counts()
# Out:
# object    13
# int64      6
# dtype: int64

# %%
data.select_dtypes('object').apply(pd.Series.nunique, axis = 0)
# Out:
# ORI                      1168
# PUB_AGENCY_NAME           952
# PUB_AGENCY_UNIT           106
# AGENCY_TYPE_NAME            7
# STATE_ABBR                 46
# STATE_NAME                 46
# DIVISION_NAME               9
# COUNTY_NAME               601
# REGION_NAME                 4
# POPULATION_GROUP_CODE      19
# POPULATION_GROUP_DESC      19
# OFFENSE_NAME                1
# OFFENSE_SUBCAT_NAME         2
# dtype: int64

# %%
data.describe(include = 'all')
# Out:
#           DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT  \
# count   4417.000000       4417            4417             214
# unique          NaN       1168             952             106
# top             NaN  TXHPD0000   State Police:     Martinsburg
# freq            NaN         89             206              13
# mean    2017.884763        NaN             NaN             NaN
# std        1.843414        NaN             NaN             NaN
# min     2013.000000        NaN             NaN             NaN
# 25%     2017.000000        NaN             NaN             NaN
# 50%     2018.000000        NaN             NaN             NaN
# 75%     2019.000000        NaN             NaN             NaN
# max     2020.000000        NaN             NaN             NaN
#
#        AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME COUNTY_NAME  \
# count              4417       4417       4417                4417        4306
# unique                7         46         46                   9         601
# top                City         TX      Texas  West South Central    HENNEPIN
# freq               3081        984        984                1172         120
# mean                NaN        NaN        NaN                 NaN         NaN
# std                 NaN        NaN        NaN                 NaN         NaN
# min                 NaN        NaN        NaN                 NaN         NaN
# 25%                 NaN        NaN        NaN                 NaN         NaN
# 50%                 NaN        NaN        NaN                 NaN         NaN
# 75%                 NaN        NaN        NaN                 NaN         NaN
# max                 NaN        NaN        NaN                 NaN         NaN
#
#        REGION_NAME POPULATION_GROUP_CODE             POPULATION_GROUP_DESC  \
# count         4417                  4417                              4417
# unique           4                    19                                19
# top          South                     2  Cities from 100,000 thru 249,999
# freq          2263                   575                               575
# mean           NaN                   NaN                               NaN
# std            NaN                   NaN                               NaN
# min            NaN                   NaN                               NaN
# 25%            NaN                   NaN                               NaN
# 50%            NaN                   NaN                               NaN
# 75%            NaN                   NaN                               NaN
# max            NaN                   NaN                               NaN
#
#         OFFENSE_SUBCAT_ID       OFFENSE_NAME  OFFENSE_SUBCAT_NAME  \
# count         4417.000000               4417                 4417
# unique                NaN                  1                    2
# top                   NaN  Human Trafficking  Commercial Sex Acts
# freq                  NaN               4417                 3558
# mean            81.194476                NaN                  NaN
# std              0.395841                NaN                  NaN
# min             81.000000                NaN                  NaN
# 25%             81.000000                NaN                  NaN
# 50%             81.000000                NaN                  NaN
# 75%             81.000000                NaN                  NaN
# max             82.000000                NaN                  NaN
#
#         ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# count    4417.000000      4417.000000    4417.000000             4417.000000
# unique           NaN              NaN            NaN                     NaN
# top              NaN              NaN            NaN                     NaN
# freq             NaN              NaN            NaN                     NaN
# mean        2.173194         0.072674       0.837673                0.032601
# std         3.128820         0.926374       2.069699                0.433354
# min        -1.000000         0.000000       0.000000                0.000000
# 25%         1.000000         0.000000       0.000000                0.000000
# 50%         1.000000         0.000000       0.000000                0.000000
# 75%         2.000000         0.000000       1.000000                0.000000
# max        67.000000        47.000000      41.000000               19.000000

# %%
data.corr()
# Out:
#                         DATA_YEAR  OFFENSE_SUBCAT_ID  ACTUAL_COUNT  \
# DATA_YEAR                1.000000          -0.022348     -0.032031
# OFFENSE_SUBCAT_ID       -0.022348           1.000000     -0.049142
# ACTUAL_COUNT            -0.032031          -0.049142      1.000000
# UNFOUNDED_COUNT          0.009679          -0.027435      0.218007
# CLEARED_COUNT           -0.028408          -0.052672      0.673369
# JUVENILE_CLEARED_COUNT  -0.028745           0.007915      0.132952
#
#                         UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# DATA_YEAR                      0.009679      -0.028408               -0.028745
# OFFENSE_SUBCAT_ID             -0.027435      -0.052672                0.007915
# ACTUAL_COUNT                   0.218007       0.673369                0.132952
# UNFOUNDED_COUNT                1.000000       0.121073                0.075325
# CLEARED_COUNT                  0.121073       1.000000                0.256106
# JUVENILE_CLEARED_COUNT         0.075325       0.256106                1.000000

# %%
sns.set()
sns.pairplot(data, size = 2.5)
plt.show();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
