# %% [markdown]
# <a href="https://colab.research.google.com/github/sarasheth/DA_LAB/blob/main/DA_LAB1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload();
data = pd.read_csv("HT_2013-2020.csv");
data
# Out:
#      <input type="file" id="files-b50c7a1b-38de-4574-91e4-06af0a108a91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b50c7a1b-38de-4574-91e4-06af0a108a91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HT_2013-2020.csv to HT_2013-2020 (1).csv
#       DATA_YEAR        ORI                           PUB_AGENCY_NAME  \
# 0          2016  MO0480600                              Independence
# 1          2016  TX2201200                                Fort Worth
# 2          2016  TX2270100                                    Austin
# 3          2019  NV0020100  Las Vegas Metropolitan Police Department
# 4          2017  AZ0070500                                  Chandler
# ...         ...        ...                                       ...
# 4412       2019  KY0370000                                  Franklin
# 4413       2019  KY0370000                                  Franklin
# 4414       2020  KY0370000                                  Franklin
# 4415       2020  KY0370000                                  Franklin
# 4416       2020  KY0370000                                  Franklin
#
#      PUB_AGENCY_UNIT AGENCY_TYPE_NAME STATE_ABBR STATE_NAME  \
# 0                NaN             City         MO   Missouri
# 1                NaN             City         TX      Texas
# 2                NaN             City         TX      Texas
# 3                NaN             City         NV     Nevada
# 4                NaN             City         AZ    Arizona
# ...              ...              ...        ...        ...
# 4412             NaN           County         KY   Kentucky
# 4413             NaN           County         KY   Kentucky
# 4414             NaN           County         KY   Kentucky
# 4415             NaN           County         KY   Kentucky
# 4416             NaN           County         KY   Kentucky
#
#            DIVISION_NAME              COUNTY_NAME REGION_NAME  \
# 0     West North Central                  JACKSON     Midwest
# 1     West South Central  PARKER; DENTON; TARRANT       South
# 2     West South Central       WILLIAMSON; TRAVIS       South
# 3               Mountain                    CLARK        West
# 4               Mountain                 MARICOPA        West
# ...                  ...                      ...         ...
# 4412  East South Central                 FRANKLIN       South
# 4413  East South Central                 FRANKLIN       South
# 4414  East South Central                 FRANKLIN       South
# 4415  East South Central                 FRANKLIN       South
# 4416  East South Central                 FRANKLIN       South
#
#      POPULATION_GROUP_CODE                     POPULATION_GROUP_DESC  \
# 0                        2          Cities from 100,000 thru 249,999
# 1                       1B          Cities from 500,000 thru 999,999
# 2                       1B          Cities from 500,000 thru 999,999
# 3                       1A                  Cities 1,000,000 or over
# 4                        2          Cities from 100,000 thru 249,999
# ...                    ...                                       ...
# 4412                    8C  Non-MSA counties from 10,000 thru 24,999
# 4413                    8C  Non-MSA counties from 10,000 thru 24,999
# 4414                    8C  Non-MSA counties from 10,000 thru 24,999
# 4415                    8C  Non-MSA counties from 10,000 thru 24,999
# 4416                    8C  Non-MSA counties from 10,000 thru 24,999
#
#       OFFENSE_SUBCAT_ID       OFFENSE_NAME    OFFENSE_SUBCAT_NAME  \
# 0                    81  Human Trafficking    Commercial Sex Acts
# 1                    82  Human Trafficking  Involuntary Servitude
# 2                    82  Human Trafficking  Involuntary Servitude
# 3                    81  Human Trafficking    Commercial Sex Acts
# 4                    81  Human Trafficking    Commercial Sex Acts
# ...                 ...                ...                    ...
# 4412                 82  Human Trafficking  Involuntary Servitude
# 4413                 82  Human Trafficking  Involuntary Servitude
# 4414                 81  Human Trafficking    Commercial Sex Acts
# 4415                 81  Human Trafficking    Commercial Sex Acts
# 4416                 81  Human Trafficking    Commercial Sex Acts
#
#       ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 0                2                0              2                       0
# 1                1                0              0                       0
# 2                2                0              0                       0
# 3               15                0              4                       0
# 4                1                0              0                       0
# ...            ...              ...            ...                     ...
# 4412             2                0              0                       0
# 4413             1                0              0                       0
# 4414             1                0              0                       0
# 4415             1                0              0                       0
# 4416             1                0              0                       0
#
# [4417 rows x 19 columns]

# %%
data.head()
# Out:
#    DATA_YEAR        ORI                           PUB_AGENCY_NAME  \
# 0       2016  MO0480600                              Independence
# 1       2016  TX2201200                                Fort Worth
# 2       2016  TX2270100                                    Austin
# 3       2019  NV0020100  Las Vegas Metropolitan Police Department
# 4       2017  AZ0070500                                  Chandler
#
#   PUB_AGENCY_UNIT AGENCY_TYPE_NAME STATE_ABBR STATE_NAME       DIVISION_NAME  \
# 0             NaN             City         MO   Missouri  West North Central
# 1             NaN             City         TX      Texas  West South Central
# 2             NaN             City         TX      Texas  West South Central
# 3             NaN             City         NV     Nevada            Mountain
# 4             NaN             City         AZ    Arizona            Mountain
#
#                COUNTY_NAME REGION_NAME POPULATION_GROUP_CODE  \
# 0                  JACKSON     Midwest                     2
# 1  PARKER; DENTON; TARRANT       South                    1B
# 2       WILLIAMSON; TRAVIS       South                    1B
# 3                    CLARK        West                    1A
# 4                 MARICOPA        West                     2
#
#               POPULATION_GROUP_DESC  OFFENSE_SUBCAT_ID       OFFENSE_NAME  \
# 0  Cities from 100,000 thru 249,999                 81  Human Trafficking
# 1  Cities from 500,000 thru 999,999                 82  Human Trafficking
# 2  Cities from 500,000 thru 999,999                 82  Human Trafficking
# 3          Cities 1,000,000 or over                 81  Human Trafficking
# 4  Cities from 100,000 thru 249,999                 81  Human Trafficking
#
#      OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  \
# 0    Commercial Sex Acts             2                0              2
# 1  Involuntary Servitude             1                0              0
# 2  Involuntary Servitude             2                0              0
# 3    Commercial Sex Acts            15                0              4
# 4    Commercial Sex Acts             1                0              0
#
#    JUVENILE_CLEARED_COUNT
# 0                       0
# 1                       0
# 2                       0
# 3                       0
# 4                       0

# %%
data.tail()
# Out:
#       DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT AGENCY_TYPE_NAME  \
# 4412       2019  KY0370000        Franklin             NaN           County
# 4413       2019  KY0370000        Franklin             NaN           County
# 4414       2020  KY0370000        Franklin             NaN           County
# 4415       2020  KY0370000        Franklin             NaN           County
# 4416       2020  KY0370000        Franklin             NaN           County
#
#      STATE_ABBR STATE_NAME       DIVISION_NAME COUNTY_NAME REGION_NAME  \
# 4412         KY   Kentucky  East South Central    FRANKLIN       South
# 4413         KY   Kentucky  East South Central    FRANKLIN       South
# 4414         KY   Kentucky  East South Central    FRANKLIN       South
# 4415         KY   Kentucky  East South Central    FRANKLIN       South
# 4416         KY   Kentucky  East South Central    FRANKLIN       South
#
#      POPULATION_GROUP_CODE                     POPULATION_GROUP_DESC  \
# 4412                    8C  Non-MSA counties from 10,000 thru 24,999
# 4413                    8C  Non-MSA counties from 10,000 thru 24,999
# 4414                    8C  Non-MSA counties from 10,000 thru 24,999
# 4415                    8C  Non-MSA counties from 10,000 thru 24,999
# 4416                    8C  Non-MSA counties from 10,000 thru 24,999
#
#       OFFENSE_SUBCAT_ID       OFFENSE_NAME    OFFENSE_SUBCAT_NAME  \
# 4412                 82  Human Trafficking  Involuntary Servitude
# 4413                 82  Human Trafficking  Involuntary Servitude
# 4414                 81  Human Trafficking    Commercial Sex Acts
# 4415                 81  Human Trafficking    Commercial Sex Acts
# 4416                 81  Human Trafficking    Commercial Sex Acts
#
#       ACTUAL_COUNT  UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 4412             2                0              0                       0
# 4413             1                0              0                       0
# 4414             1                0              0                       0
# 4415             1                0              0                       0
# 4416             1                0              0                       0

# %%
data.isnull().sum()
# Out:
# DATA_YEAR                    0
# ORI                          0
# PUB_AGENCY_NAME              0
# PUB_AGENCY_UNIT           4203
# AGENCY_TYPE_NAME             0
# STATE_ABBR                   0
# STATE_NAME                   0
# DIVISION_NAME                0
# COUNTY_NAME                111
# REGION_NAME                  0
# POPULATION_GROUP_CODE        0
# POPULATION_GROUP_DESC        0
# OFFENSE_SUBCAT_ID            0
# OFFENSE_NAME                 0
# OFFENSE_SUBCAT_NAME          0
# ACTUAL_COUNT                 0
# UNFOUNDED_COUNT              0
# CLEARED_COUNT                0
# JUVENILE_CLEARED_COUNT       0
# dtype: int64

# %%
data.size
# Out:
# 83923

# %%
data.shape
# Out:
# (4417, 19)

# %%
data.describe()
# Out:
#          DATA_YEAR  OFFENSE_SUBCAT_ID  ACTUAL_COUNT  UNFOUNDED_COUNT  \
# count  4417.000000        4417.000000   4417.000000      4417.000000
# mean   2017.884763          81.194476      2.173194         0.072674
# std       1.843414           0.395841      3.128820         0.926374
# min    2013.000000          81.000000     -1.000000         0.000000
# 25%    2017.000000          81.000000      1.000000         0.000000
# 50%    2018.000000          81.000000      1.000000         0.000000
# 75%    2019.000000          81.000000      2.000000         0.000000
# max    2020.000000          82.000000     67.000000        47.000000
#
#        CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# count    4417.000000             4417.000000
# mean        0.837673                0.032601
# std         2.069699                0.433354
# min         0.000000                0.000000
# 25%         0.000000                0.000000
# 50%         0.000000                0.000000
# 75%         1.000000                0.000000
# max        41.000000               19.000000

# %%
data.columns
# Out:
# Index(['DATA_YEAR', 'ORI', 'PUB_AGENCY_NAME', 'PUB_AGENCY_UNIT',
#        'AGENCY_TYPE_NAME', 'STATE_ABBR', 'STATE_NAME', 'DIVISION_NAME',
#        'COUNTY_NAME', 'REGION_NAME', 'POPULATION_GROUP_CODE',
#        'POPULATION_GROUP_DESC', 'OFFENSE_SUBCAT_ID', 'OFFENSE_NAME',
#        'OFFENSE_SUBCAT_NAME', 'ACTUAL_COUNT', 'UNFOUNDED_COUNT',
#        'CLEARED_COUNT', 'JUVENILE_CLEARED_COUNT'],
#       dtype='object')

# %%
data.dropna(inplace = True)

# %%
data.shape
# Out:
# (181, 19)

# %%
data.isnull().sum()
# Out:
# DATA_YEAR                 0
# ORI                       0
# PUB_AGENCY_NAME           0
# PUB_AGENCY_UNIT           0
# AGENCY_TYPE_NAME          0
# STATE_ABBR                0
# STATE_NAME                0
# DIVISION_NAME             0
# COUNTY_NAME               0
# REGION_NAME               0
# POPULATION_GROUP_CODE     0
# POPULATION_GROUP_DESC     0
# OFFENSE_SUBCAT_ID         0
# OFFENSE_NAME              0
# OFFENSE_SUBCAT_NAME       0
# ACTUAL_COUNT              0
# UNFOUNDED_COUNT           0
# CLEARED_COUNT             0
# JUVENILE_CLEARED_COUNT    0
# dtype: int64

# %%
data
# Out:
#       DATA_YEAR        ORI PUB_AGENCY_NAME PUB_AGENCY_UNIT AGENCY_TYPE_NAME  \
# 45         2018  MI3803800   State Police:  Jackson County     State Police
# 46         2019  MI3803800   State Police:  Jackson County     State Police
# 47         2020  MI3803800   State Police:  Jackson County     State Police
# 96         2020  MI4104100   State Police:     Kent County     State Police
# 187        2019  WVWSP4300   State Police:          Romney     State Police
# ...         ...        ...             ...             ...              ...
# 4195       2020  VA083SP00   State Police:  Russell County     State Police
# 4196       2020  VA084SP00   State Police:    Scott County     State Police
# 4213       2019  MI8208200   State Police:    Wayne County     State Police
# 4214       2020  MI8208200   State Police:    Wayne County     State Police
# 4301       2016  DE303SP00   State Police:   Sussex County     State Police
#
#      STATE_ABBR     STATE_NAME       DIVISION_NAME COUNTY_NAME REGION_NAME  \
# 45           MI       Michigan  East North Central     JACKSON     Midwest
# 46           MI       Michigan  East North Central     JACKSON     Midwest
# 47           MI       Michigan  East North Central     JACKSON     Midwest
# 96           MI       Michigan  East North Central        KENT     Midwest
# 187          WV  West Virginia      South Atlantic   HAMPSHIRE       South
# ...         ...            ...                 ...         ...         ...
# 4195         VA       Virginia      South Atlantic     RUSSELL       South
# 4196         VA       Virginia      South Atlantic       SCOTT       South
# 4213         MI       Michigan  East North Central       WAYNE     Midwest
# 4214         MI       Michigan  East North Central       WAYNE     Midwest
# 4301         DE       Delaware      South Atlantic      SUSSEX       South
#
#      POPULATION_GROUP_CODE          POPULATION_GROUP_DESC  OFFENSE_SUBCAT_ID  \
# 45                      9D      MSA counties under 10,000                 81
# 46                      9D      MSA counties under 10,000                 82
# 47                      9D      MSA counties under 10,000                 81
# 96                      9D      MSA counties under 10,000                 81
# 187                     9D      MSA counties under 10,000                 81
# ...                    ...                            ...                ...
# 4195                    8D  Non-MSA counties under 10,000                 81
# 4196                    9D      MSA counties under 10,000                 81
# 4213                    9D      MSA counties under 10,000                 81
# 4214                    9D      MSA counties under 10,000                 81
# 4301                    9A   MSA counties 100,000 or over                 81
#
#            OFFENSE_NAME    OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  UNFOUNDED_COUNT  \
# 45    Human Trafficking    Commercial Sex Acts             2                0
# 46    Human Trafficking  Involuntary Servitude             1                0
# 47    Human Trafficking    Commercial Sex Acts             1                0
# 96    Human Trafficking    Commercial Sex Acts             1                0
# 187   Human Trafficking    Commercial Sex Acts             1                0
# ...                 ...                    ...           ...              ...
# 4195  Human Trafficking    Commercial Sex Acts             1                0
# 4196  Human Trafficking    Commercial Sex Acts             1                0
# 4213  Human Trafficking    Commercial Sex Acts             1                0
# 4214  Human Trafficking    Commercial Sex Acts             1                0
# 4301  Human Trafficking    Commercial Sex Acts             7                0
#
#       CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 45                0                       0
# 46                0                       0
# 47                0                       0
# 96                0                       0
# 187               0                       0
# ...             ...                     ...
# 4195              0                       0
# 4196              0                       0
# 4213              0                       0
# 4214              0                       0
# 4301              0                       0
#
# [181 rows x 19 columns]

# %%
fig = px.bar(data[:15], x="DATA_YEAR", y="DIVISION_NAME")
fig.update_layout(
    title='Human Trafficking',
    yaxis=dict(
        title='DIVISION_NAME'
    )
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="129f67e8-8884-488a-8fce-2eecef405ea5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("129f67e8-8884-488a-8fce-2eecef405ea5")) {                    Plotly.newPlot(                        "129f67e8-8884-488a-8fce-2eecef405ea5",                        [{"alignmentgroup":"True","hovertemplate":"DATA_YEAR=%{x}<br>DIVISION_NAME=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2020,2019,2017,2017,2020,2014,2015,2018,2018,2018,2018,2020],"xaxis":"x","y":["East North Central","East North Central","East North Central","East North Central","South Atlantic","South Atlantic","South Atlantic","South Atlantic","East North Central","East North Central","East North Central","East North Central","East North Central","South Atlantic","East North Central"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram ...
